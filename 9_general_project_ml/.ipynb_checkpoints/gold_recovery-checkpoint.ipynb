# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Технологический-процесс" data-toc-modified-id="Технологический-процесс-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Технологический процесс</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание данных</a></span><ul class="toc-item"><li><span><a href="#Технологический-процесс" data-toc-modified-id="Технологический-процесс-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Технологический процесс</a></span></li><li><span><a href="#Параметры-этапов" data-toc-modified-id="Параметры-этапов-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Параметры этапов</a></span></li><li><span><a href="#Наименование-признаков" data-toc-modified-id="Наименование-признаков-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Наименование признаков</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Импорт-библиотек:" data-toc-modified-id="Импорт-библиотек:-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Импорт библиотек:</a></span></li><li><span><a href="#Откроем-файлы:" data-toc-modified-id="Откроем-файлы:-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>Откроем файлы:</a></span></li><li><span><a href="#Расчёт-эффективности:" data-toc-modified-id="Расчёт-эффективности:-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>Расчёт эффективности:</a></span></li><li><span><a href="#Посмотрим-на-размер-выборок:" data-toc-modified-id="Посмотрим-на-размер-выборок:-3.0.4"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>Посмотрим на размер выборок:</a></span></li><li><span><a href="#Восстанавливаем-пропущенные-значения:" data-toc-modified-id="Восстанавливаем-пропущенные-значения:-3.0.5"><span class="toc-item-num">3.0.5&nbsp;&nbsp;</span>Восстанавливаем пропущенные значения:</a></span></li><li><span><a href="#Добавляем-целевые-признаки-в-тестовую-выборку:" data-toc-modified-id="Добавляем-целевые-признаки-в-тестовую-выборку:-3.0.6"><span class="toc-item-num">3.0.6&nbsp;&nbsp;</span>Добавляем целевые признаки в тестовую выборку:</a></span></li><li><span><a href="#Удалим-из-тренировочной-выборки-столбцы-которые-отсутствуют-в-тестовой:" data-toc-modified-id="Удалим-из-тренировочной-выборки-столбцы-которые-отсутствуют-в-тестовой:-3.0.7"><span class="toc-item-num">3.0.7&nbsp;&nbsp;</span>Удалим из тренировочной выборки столбцы которые отсутствуют в тестовой:</a></span></li></ul></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-концентрации-металлов-на-различных-этапах-очистки:" data-toc-modified-id="Изменение-концентрации-металлов-на-различных-этапах-очистки:-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изменение концентрации металлов на различных этапах очистки:</a></span><ul class="toc-item"><li><span><a href="#Au:" data-toc-modified-id="Au:-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Au:</a></span></li><li><span><a href="#Ag:" data-toc-modified-id="Ag:-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Ag:</a></span></li><li><span><a href="#Pb:" data-toc-modified-id="Pb:-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Pb:</a></span></li><li><span><a href="#Сравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках:" data-toc-modified-id="Сравнение-распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках:-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках:</a></span></li><li><span><a href="#Суммарная-концентрация-всех-веществ-на-стадии:-исходного-сырья,-черновом-и-финальном-концентратах." data-toc-modified-id="Суммарная-концентрация-всех-веществ-на-стадии:-исходного-сырья,-черновом-и-финальном-концентратах.-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Суммарная концентрация всех веществ на стадии: исходного сырья, черновом и финальном концентратах.</a></span></li></ul></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Метрика-качества-sMAPE:" data-toc-modified-id="Метрика-качества-sMAPE:-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>Метрика качества sMAPE:</a></span></li><li><span><a href="#Функция-для-вычисления-sMAPE:" data-toc-modified-id="Функция-для-вычисления-sMAPE:-5.0.2"><span class="toc-item-num">5.0.2&nbsp;&nbsp;</span>Функция для вычисления sMAPE:</a></span></li><li><span><a href="#Определим-признаки:" data-toc-modified-id="Определим-признаки:-5.0.3"><span class="toc-item-num">5.0.3&nbsp;&nbsp;</span>Определим признаки:</a></span></li></ul></li><li><span><a href="#Обучение-моделей:" data-toc-modified-id="Обучение-моделей:-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Обучение моделей:</a></span></li><li><span><a href="#Дерево-решений:" data-toc-modified-id="Дерево-решений:-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Дерево решений:</a></span></li><li><span><a href="#Случайный-лес:" data-toc-modified-id="Случайный-лес:-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Случайный лес:</a></span></li><li><span><a href="#Линейная-регрессия:" data-toc-modified-id="Линейная-регрессия:-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Линейная регрессия:</a></span></li><li><span><a href="#Проверка-качества-модели-на-тестовой-выборке:" data-toc-modified-id="Проверка-качества-модели-на-тестовой-выборке:-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Проверка качества модели на тестовой выборке:</a></span></li><li><span><a href="#Вывод:" data-toc-modified-id="Вывод:-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Вывод:</a></span></li><</div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Необходимо подготовить прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используем данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Нам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.

# %% [markdown]
# * gold_recovery_train_new.csv — обучающая выборка
# * gold_recovery_test_new.csv — тестовая выборка
# * gold_recovery_full_new.csv — исходные данные

# %% [markdown]
# ## Технологический процесс

# %% [markdown]
# Как золото получают из руды?
# Когда добытая руда проходит первичную обработку, получается дроблёная смесь. Её отправляют на флотацию (обогащение) и двухэтапную очистку.
#
# Опишем каждую стадию:
# 1. Флотация
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
# 2. Очистка
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.

# %% [markdown]
# ## Описание данных
# ### Технологический процесс
# * Rougher feed — исходное сырье
# * Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
#
#     * Xanthate **— ксантогенат (промотер, или активатор флотации);
#     * Sulphate — сульфат (на данном производстве сульфид натрия);
#     * Depressant — депрессант (силикат натрия).
#
# * Rougher process (англ. «грубый процесс») — флотация
# * Rougher tails — отвальные хвосты
# * Float banks — флотационная установка
# * Cleaner process — очистка
# * Rougher Au — черновой концентрат золота
# * Final Au — финальный концентрат золота
# ### Параметры этапов
# * air amount — объём воздуха
# * fluid levels — уровень жидкости
# * feed size — размер гранул сырья
# * feed rate — скорость подачи
# ### Наименование признаков
#
# Наименование признаков должно быть такое:
# `[этап].[тип_параметра].[название_параметра]`
#
# Пример: `rougher.input.feed_ag`
#
# Возможные значения для блока `[этап]`:
#
# * rougher — флотация
# * primary_cleaner — первичная очистка
# * secondary_cleaner — вторичная очистка
# * final — финальные характеристики
#
# Возможные значения для блока [тип_параметра]:
# * input — параметры сырья
# * output — параметры продукта
# * state — параметры, характеризующие текущее состояние этапа
# * calculation — расчётные характеристики

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# * 1.2. Проверьте, что эффективность обогащения рассчитана правильно. Вычислите её на обучающей выборке для признака rougher.output.recovery. Найдите MAE между вашими расчётами и значением признака. Опишите выводы.
# * 1.3. Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?
# * 1.4. Проведите предобработку данных.

# %% [markdown]
# #### Импорт библиотек:

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

from numpy.random import RandomState
from scipy import stats as st
from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, mean_absolute_error
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# #### Откроем файлы:
# На локальном Jupyter или ЯП Jupyter.
#
# Используем колонку `data` как индекс. Плюс исключим её из признаков.

# %%
try:
    df_train = pd.read_csv('C:/Users/User/Downloads/gold_recovery_train_new.csv', index_col='date', parse_dates=True)
    df_test = pd.read_csv('C:/Users/User/Downloads/gold_recovery_test_new.csv', index_col='date', parse_dates=True)
    df = pd.read_csv('C:/Users/User/Downloads/gold_recovery_full_new.csv', index_col='date', parse_dates=True)
except:
    df_train = pd.read_csv('/datasets/gold_recovery_train_new.csv', index_col='date', parse_dates=True)
    df_test = pd.read_csv('/datasets/gold_recovery_test_new.csv', index_col='date', parse_dates=True)
    df = pd.read_csv('/datasets/gold_recovery_full_new.csv', index_col='date', parse_dates=True)

# %% [markdown]
# #### Расчёт эффективности:

# %% [markdown]
# Нужно смоделировать процесс восстановления золота из золотосодержащей руды.
# Эффективность обогащения рассчитывается по формуле
#
# ${\large Recovery=\dfrac{C(F-T)}{F(C-T)}100\%}$
#
# где:
# * C — доля золота в концентрате после флотации/очистки;
# * F — доля золота в сырье/концентрате до флотации/очистки;
# * T — доля золота в отвальных хвостах после флотации/очистки.
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %%
c = df_train['rougher.output.concentrate_au']
f = df_train['rougher.input.feed_au']
t = df_train['rougher.output.tail_au']
recovery = ((c * (f - t)) / (f * (c - t))) * 100
print('MAE: ', mean_absolute_error(df_train['rougher.output.recovery'], recovery))
# Out:
# MAE:  9.73512347450521e-15

# %% [markdown]
# Можно считать что эффективность обогащения рассчитана правильно.

# %% [markdown]
# #### Посмотрим на размер выборок:

# %%
df_train.shape, df_test.shape, df.shape
# Out:
# ((14149, 86), (5290, 52), (19439, 86))

# %% [markdown]
# Разделение выборок адекватное. Количество столбцов в тестовой выборке меньше т.к. `Некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже. Из-за этого в тестовой выборке отсутствуют некоторые признаки, которые могут быть в обучающей. Также в тестовом наборе нет целевых признаков.`

# %%
df_train.info()
df_test.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14149 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         14148 non-null  float64
#  1   final.output.concentrate_pb                         14148 non-null  float64
#  2   final.output.concentrate_sol                        13938 non-null  float64
#  3   final.output.concentrate_au                         14149 non-null  float64
#  4   final.output.recovery                               14149 non-null  float64
#  5   final.output.tail_ag                                14149 non-null  float64
#  6   final.output.tail_pb                                14049 non-null  float64
#  7   final.output.tail_sol                               14144 non-null  float64
# ...

# %% [markdown]
# Есть пропуски. Заполним их методом `ffill` т.к. в задании сказано: `Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.`
#
# Также в тестовой выборке отсутствуют целевые признаки. Восстановим их из исходного датафрейма для возможности проверки качества модели.

# %% [markdown]
# #### Восстанавливаем пропущенные значения:

# %%
df_train = df_train.fillna(method='ffill')
df_test = df_test.fillna(method='ffill')
df = df.fillna(method='ffill')

# %% [markdown]
# #### Добавляем целевые признаки в тестовую выборку:

# %%
columns = ['final.output.recovery', 'rougher.output.recovery']
df_test = df_test.join(df[columns])

# %% [markdown]
# #### Удалим из тренировочной выборки столбцы которые отсутствуют в тестовой:
# т.к. если модель обучится на данных, которых нет в тесте, она будет некорректно работать.

# %%
df_train_ex = df_train.copy()
df_train_ex = df_train_ex.drop(columns=list(df_test.columns))
df_train = df_train.drop(columns=list(df_train_ex.columns))
df_train.shape, df_test.shape, df.shape
# Out:
# ((14149, 54), (5290, 54), (19439, 86))

# %% [markdown]
# Теперь данные в порядке.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# * 2.1. Посмотрите, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах очистки. Опишите выводы.
# * 2.2.  Сравните распределения размеров гранул сырья на обучающей и тестовой выборках. Если распределения сильно отличаются друг от друга, оценка модели будет неправильной.
# * 2.3. Исследуйте суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %% [markdown]
# ### Изменение концентрации металлов на различных этапах очистки:

# %% [markdown]
# #### Au:

# %%
plt.figure(figsize=(14, 7))
sns.kdeplot(df['rougher.input.feed_au'], label='Исходное сырье')
sns.kdeplot(df['rougher.output.concentrate_au'], label='Черновой концентрат')
sns.kdeplot(df['primary_cleaner.output.concentrate_au'], label='Первичная очистка')
sns.kdeplot(df['final.output.concentrate_au'], label='Финальный концентрат')
plt.title('Концентрация au на разных этапах очистки')
plt.legend()
plt.xlabel('Концентрация металла')
plt.ylabel('Плотность вероятности')
plt.show()

df[['rougher.input.feed_au', 'rougher.output.concentrate_au', 'primary_cleaner.output.concentrate_au', 'final.output.concentrate_au']].describe().T
# Out:
#                                          count       mean       std   min  \
# rougher.input.feed_au                  19439.0   8.266097  1.955092  0.01
# rougher.output.concentrate_au          19439.0  19.772000  3.753600  0.00
# primary_cleaner.output.concentrate_au  19439.0  32.119400  5.627611  0.00
# final.output.concentrate_au            19439.0  44.076513  5.129784  0.00
#
#                                              25%        50%        75%  \
# rougher.input.feed_au                   6.854384   8.125839   9.769917
# rougher.output.concentrate_au          18.802523  20.280214  21.717843
# primary_cleaner.output.concentrate_au  30.463140  32.841295  35.048006
# final.output.concentrate_au            43.402215  45.011244  46.275313
#
#                                              max
# rougher.input.feed_au                  13.731330
# rougher.output.concentrate_au          28.824507
# primary_cleaner.output.concentrate_au  45.933934
# ...

# %% [markdown]
# С каждым этапом концентрация золота увеличивается. Так и должно быть.

# %% [markdown]
# #### Ag:

# %%
plt.figure(figsize=(14, 7))
sns.kdeplot(df['rougher.input.feed_ag'], label='Исходное сырье')
sns.kdeplot(df['rougher.output.concentrate_ag'], label='Черновой концентрат')
sns.kdeplot(df['primary_cleaner.output.concentrate_ag'], label='Первичная очистка')
sns.kdeplot(df['final.output.concentrate_ag'], label='Финальный концентрат')
plt.title('Концентрация ag на разных этапах очистки')
plt.legend()
plt.xlabel('Концентрация металла')
plt.ylabel('Плотность вероятности')
plt.show()

df[['rougher.input.feed_ag', 'rougher.output.concentrate_ag', 'primary_cleaner.output.concentrate_ag', 'final.output.concentrate_ag']].describe().T
# Out:
#                                          count       mean       std   min  \
# rougher.input.feed_ag                  19439.0   8.794927  1.936847  0.01
# rougher.output.concentrate_ag          19439.0  11.994759  2.733862  0.00
# primary_cleaner.output.concentrate_ag  19439.0   8.442408  2.054465  0.00
# final.output.concentrate_ag            19439.0   5.168387  1.372362  0.00
#
#                                              25%        50%        75%  \
# rougher.input.feed_ag                   7.237967   8.593574  10.213771
# rougher.output.concentrate_ag          10.628337  12.098115  13.736996
# primary_cleaner.output.concentrate_ag   7.263288   8.507298   9.809001
# final.output.concentrate_ag             4.251000   5.066039   5.895401
#
#                                              max
# rougher.input.feed_ag                  14.596026
# rougher.output.concentrate_ag          24.480271
# primary_cleaner.output.concentrate_ag  16.081632
# ...

# %% [markdown]
# Концентрация серебра увеличивается до этапов очистки, потом снижается. Вероятно целью является золото и так и должно происходить.

# %% [markdown]
# #### Pb:

# %%
plt.figure(figsize=(14, 7))
sns.kdeplot(df['rougher.input.feed_pb'], label='Исходное сырье')
sns.kdeplot(df['rougher.output.concentrate_pb'], label='Черновой концентрат')
sns.kdeplot(df['primary_cleaner.output.concentrate_pb'], label='Первичная очистка')
sns.kdeplot(df['final.output.concentrate_pb'], label='Финальный концентрат')
plt.title('Концентрация pb на разных этапах очистки')
plt.legend()
plt.xlabel('Концентрация металла')
plt.ylabel('Плотность вероятности')
plt.show()

df[['rougher.input.feed_pb', 'rougher.output.concentrate_pb', 'primary_cleaner.output.concentrate_pb', 'final.output.concentrate_pb']].describe().T
# Out:
#                                          count      mean       std   min  \
# rougher.input.feed_pb                  19439.0  3.585096  1.062972  0.01
# rougher.output.concentrate_pb          19439.0  7.606272  1.796757  0.00
# primary_cleaner.output.concentrate_pb  19439.0  9.810317  2.572253  0.00
# final.output.concentrate_pb            19439.0  9.978821  1.669228  0.00
#
#                                             25%        50%        75%  \
# rougher.input.feed_pb                  2.872178   3.528235   4.241005
# rougher.output.concentrate_pb          6.725987   7.742580   8.565199
# primary_cleaner.output.concentrate_pb  8.676500  10.142270  11.416298
# final.output.concentrate_pb            9.137225  10.102264  11.035644
#
#                                              max
# rougher.input.feed_pb                   7.142594
# rougher.output.concentrate_pb          13.617072
# primary_cleaner.output.concentrate_pb  17.081278
# final.output.concentrate_pb            17.031899

# %% [markdown]
# Концентрация свинца увеличивается. Вероятно связано с удельным весом металлов т.е. золото и свинец тяжелые и на этапах очистки их концентрация растет.

# %% [markdown]
# #### Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках:

# %%
plt.figure(figsize=(14, 7))
sns.kdeplot(df_train['rougher.input.feed_size'], label='Размер гранул исходного сырья df_train')
sns.kdeplot(df_test['rougher.input.feed_size'], label='Размер гранул исходного сырья df_test')

plt.title('Распределение размеров гранул сырья на обучающей и тестовой выборках')
plt.legend()
plt.xlabel('Размер гранул')
plt.ylabel('Плотность вероятности')
plt.show()

# %%
plt.figure(figsize=(14, 7))
sns.kdeplot(df_train['primary_cleaner.input.feed_size'], label='Размер гранул первичной очистки сырья df_train')
sns.kdeplot(df_test['primary_cleaner.input.feed_size'], label='Размер гранул первичной очистки сырья df_test')

plt.title('Распределение размеров гранул сырья на обучающей и тестовой выборках')
plt.legend()
plt.xlabel('Размер гранул')
plt.ylabel('Плотность вероятности')

plt.show()

# %% [markdown]
# Распределения отличаются но, думаю, нам это не помешает.

# %% [markdown]
# #### Суммарная концентрация всех веществ на стадии: исходного сырья, черновом и финальном концентратах.

# %%
df['rougher_in_total'] = df[['rougher.input.feed_au', 'rougher.input.feed_ag', 'rougher.input.feed_pb', 'rougher.input.feed_sol']].sum(axis=1)
df['rougher_out_total'] = df[['rougher.output.concentrate_au', 'rougher.output.concentrate_ag', 'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol']].sum(axis=1)
df['final_out_total'] = df[['final.output.concentrate_au', 'final.output.concentrate_ag', 'final.output.concentrate_pb', 'final.output.concentrate_sol']].sum(axis=1)

# %%
plt.figure(figsize=(14, 7))
sns.kdeplot(df['rougher_in_total'], label='Исходное сырье')
sns.kdeplot(df['rougher_out_total'], label='Черновой концентрат')
sns.kdeplot(df['final_out_total'], label='Финальный концентрат')
plt.title('Суммарная концентрация металлов на разных этапах')
plt.legend()
plt.xlabel('Суммарная концентрация')
plt.ylabel('Плотность вероятности')
plt.show()
df[['rougher_in_total', 'rougher_out_total', 'final_out_total']].describe().T
# Out:
#                      count       mean        std   min        25%        50%  \
# rougher_in_total   19439.0  57.320789   7.212680  0.04  53.557679  57.594391
# rougher_out_total  19439.0  68.170865  12.491279  0.00  66.012495  70.181495
# final_out_total    19439.0  68.653624   7.427536  0.00  67.932362  69.598444
#
#                          75%        max
# rougher_in_total   61.953459  76.978947
# rougher_out_total  74.356904  88.140119
# final_out_total    71.368472  80.210644

# %% [markdown]
# Суммарная концентрация металлов увеличивается с каждым этапом

# %%
df_train = df_train[(df_train == 0).sum(axis=1)==0]

# %% [markdown]
# ## Модель

# %% [markdown]
# * 3.1. Напишите функцию для вычисления итоговой sMAPE.
# * 3.2. Обучите разные модели и оцените их качество кросс-валидацией. Выберите лучшую модель и проверьте её на тестовой выборке.

# %% [markdown]
# #### Метрика качества sMAPE:

# %% [markdown]
# Для решения задачи введём новую метрику качества — sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).
#
# Она похожа на MAE, но выражается не в абсолютных величинах, а в относительных. Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания.
# Метрика sMAPE вычисляется так:
#
# ${\large sMAPE = \dfrac{1}{N}{\displaystyle\sum_{i=1}^N} \dfrac{|y_i - \hat{y_i}|}{(|y_i| - |\hat{y_i}|)/2}100\%}$
#
# Нужно спрогнозировать сразу две величины:
# эффективность обогащения чернового концентрата `rougher.output.recovery`;
# эффективность обогащения финального концентрата `final.output.recovery`.
# Итоговая метрика складывается из двух величин:
#
# *итоговое sMAPE = 100% * sMAPE(rougher) + 75% * sMAPE(final)*

# %% [markdown]
# #### Функция для вычисления sMAPE:

# %%
def smape(target, predictions):
    return 100 / len(target) * np.sum(2 * np.abs(predictions - target) / (np.abs(target) + np.abs(predictions)))

# %%
def result_smape(smape_rougher, smape_final):
    return 0.25 * smape_rougher + 0.75 * smape_final

# %%
smape_score = make_scorer(smape)
state = RandomState(1984)

# %% [markdown]
# #### Определим признаки:

# %%
features_train = df_train.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
target_train_rougher = df_train['rougher.output.recovery']
target_train_final = df_train['final.output.recovery']

# %%
features_test = df_test.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
target_test_rougher = df_test['rougher.output.recovery']
target_test_final = df_test['final.output.recovery']

# %% [markdown]
# ### Обучение моделей:

# %% [markdown]
# ### Дерево решений:

# %%
total_smape_dtr = 100
best_depth_dtr = 0

for dept in range(1, 5):
    
    dtr_rougher = DecisionTreeRegressor(max_depth=dept, random_state=state)
    scores_rougher = cross_val_score(dtr_rougher, features_train, target_train_rougher, scoring=smape_score, cv=5).mean()
    
    dtr_final = DecisionTreeRegressor(max_depth=dept, random_state=state,)
    scores_final = cross_val_score(dtr_final, features_train, target_train_final, scoring=smape_score, cv=5).mean()
    
    total_smape = result_smape(scores_rougher, scores_final)
    
    if total_smape < total_smape_dtr:
        total_smape_dtr = total_smape
        best_depth_dtr = dept

print(best_depth_dtr, 'Итоговая sMAPE - ', total_smape_dtr)
# Out:
# 3 Итоговая sMAPE -  8.901606548660821

# %% [markdown]
# ### Случайный лес:

# %%
# %%time
total_smape_rfr = 100
best_est_rfr = 0
best_depth_rfr = 0

for est in range(10, 50, 20):
    for dept in range(1, 6, 2):
        
        rfr_rougher = RandomForestRegressor(n_estimators=est, max_depth=dept, random_state=state, n_jobs=-1)
        scores_rougher = cross_val_score(rfr_rougher, features_train, target_train_rougher, scoring=smape_score, cv=5).mean()

        rfr_final = RandomForestRegressor(n_estimators=est, max_depth=dept, random_state=state, n_jobs=-1)
        scores_final = cross_val_score(rfr_final, features_train, target_train_final, scoring=smape_score, cv=5).mean()
        
        total_smape = result_smape(scores_rougher, scores_final)
        
        if total_smape < total_smape_rfr:
            total_smape_rfr = total_smape
            best_est_rfr = est
            best_depth_rfr = dept
        
print(best_est_rfr, best_depth_rfr, 'Итоговая sMAPE - ', total_smape_rfr)
# Out:
# 10 3 Итоговая sMAPE -  8.533498933696743
# Wall time: 1min 25s

# %% [markdown]
# ### Линейная регрессия:

# %%
lr_rougher = LinearRegression()
scores_rougher = cross_val_score(lr_rougher, features_train, target_train_rougher, scoring=smape_score, cv=5).mean()

lr_final = LinearRegression()
scores_final = cross_val_score(lr_final, features_train, target_train_final, scoring=smape_score, cv=5).mean()

total_smape_lr = result_smape(scores_rougher, scores_final)

print('Итоговая sMAPE - ', total_smape_lr)
# Out:
# Итоговая sMAPE -  10.011521815377849

# %% [markdown]
# Из данных вариантов Случайный лес показывает лучший результат с глубиной 3 и количеством 10. Используем эту модель с выбранными параметрами.

# %% [markdown]
# ### Проверка качества модели на тестовой выборке:

# %%
rfr_rougher = RandomForestRegressor(n_estimators=30, max_depth=5, random_state=state, n_jobs=-1)
rfr_rougher.fit(features_train, target_train_rougher)
predictions_rougher = rfr_rougher.predict(features_test)

rfr_final = RandomForestRegressor(n_estimators=30, max_depth=5, random_state=state, n_jobs=-1)
rfr_final.fit(features_train, target_train_final)
predictions_final = rfr_final.predict(features_test)

scores_rougher = smape(target_test_rougher, predictions_rougher)
scores_final = smape(target_test_final, predictions_final)

total_smape = result_smape(scores_rougher, scores_final)

print('Итоговая sMAPE - ', total_smape)
# Out:
# Итоговая sMAPE -  9.290168378261962

# %%
d_rougher = DummyRegressor(strategy='mean')
d_rougher.fit(features_train, target_train_rougher)
predictions_rougher = d_rougher.predict(features_test)

d_final = DummyRegressor(strategy='mean')
d_final.fit(features_train, target_train_final)
predictions_final = d_final.predict(features_test)

scores_rougher = smape(target_test_rougher, predictions_rougher)
scores_final = smape(target_test_final, predictions_final)

total_smape = result_smape(scores_rougher, scores_final)

print('Итоговая sMAPE - ', total_smape)
# Out:
# Итоговая sMAPE -  9.81930572408775

# %% [markdown]
# Получается наша модель лучше константной

# %% [markdown]
# ### Вывод:

# %% [markdown]
# В данном проекте мы подготовили прототип модели машинного обучения которая должна предсказать коэффициент восстановления золота из золотосодержащей руды. Это поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Проверили что эффективность обогащения рассчитана правильно, рассчитав MAE между нашими расчётами и значением признака.
# Провели предобработку данных: удалили отстутствующие в тестовой выборке признаки из тренировочной, восстановили целевые признаки в тренировочной выборке из полного датасета, восстановили пропущенные значения.
#
# Проанализировали как меняется концентрация металлов на различных этапах очистки: выяснили что более тяжелые металлы концентрируются на каждом этапе больше остальных.
#
# Написали функцию для вычисления итоговой sMAPE. Обучили модели с кросс валидацией: дерево решений, случайний лес. И линейную регрессию.
#
# Выбрали лучшую модель - случайный лес с параметрами глубины 3 и количеством 10. Проверили ее на тестовой выборке и получили значение симметричного среднего абсолютного процентного отклонения (sMAPE) 9.29. Также модель выдержала проверку по сравнению с константной моделью.
